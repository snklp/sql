# %% [markdown]
# **Loads SQL extension**

# %%
# %load_ext sql

# %% [markdown]
# **Creating connection to postgres database 'dvdrental'**

# %%
# %sql postgresql://postgres:786420@localhost/dvdrental

# %% [markdown]
# ### 1. Aggregate Functions

# %% [markdown]
# - **COUNT** (number of rows in a particular column)
# - **SUM** (adds together all values in a particular column)
# - **MIN** and **MAX** (returns lowest and highest values in a particular column)
# - **AVG** (returns avg of a group of selected values)

# %% [markdown]
# **COUNT** *(with all columns using *) gives count of all the rows.

# %%
# %%sql
#
# SELECT COUNT(*) FROM address
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 1 rows affected.
# [(603,)]

# %% [markdown]
# **COUNT** *(with individual column)* gives count of all the non null rows.

# %%
# %%sql
#
# SELECT COUNT(address2) FROM address
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 1 rows affected.
# [(599,)]

# %% [markdown]
# ***same as above just w/ changed column name of rows count***

# %%
# %%sql
#
# SELECT COUNT(address2) AS count_of_address2 FROM address
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 1 rows affected.
# [(599,)]

# %% [markdown]
# **SUM** *(can only be applied on columns containing numerical values)*

# %%
# %%sql
#
# SELECT SUM(rental_rate) FROM film
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 1 rows affected.
# [(Decimal('2980.00'),)]

# %% [markdown]
# **MIN and MAX**

# %%
# %%sql
#
# SELECT MIN(rental_rate) AS min_rental_rate,
#   MAX(rental_rate) AS max_rental_rate
# FROM film
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 1 rows affected.
# [(Decimal('0.99'), Decimal('4.99'))]

# %% [markdown]
# **AVG** *(can only be applied on numerical columns & it ignores the nulls completely)*

# %%
# %%sql
#
# SELECT AVG(rental_rate) FROM film
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 1 rows affected.
# [(Decimal('2.9800000000000000'),)]

# %% [markdown]
# ***same as above as AVG ignores nulls by default***

# %%
# %%sql
#
# SELECT AVG(rental_rate) FROM film WHERE rental_rate IS NOT NULL
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 1 rows affected.
# [(Decimal('2.9800000000000000'),)]

# %% [markdown]
# ### 2. GROUP BY
# **(Helps in seperating data into groups & aggregating them independently)**

# %%
# %%sql
#
# SELECT *
# FROM payment
# LIMIT 10
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 10 rows affected.
# [(17503, 341, 2, 1520, Decimal('7.99'), datetime.datetime(2007, 2, 15, 22, 25, 46, 996577)),
#  (17504, 341, 1, 1778, Decimal('1.99'), datetime.datetime(2007, 2, 16, 17, 23, 14, 996577)),
#  (17505, 341, 1, 1849, Decimal('7.99'), datetime.datetime(2007, 2, 16, 22, 41, 45, 996577)),
#  (17506, 341, 2, 2829, Decimal('2.99'), datetime.datetime(2007, 2, 19, 19, 39, 56, 996577)),
#  (17507, 341, 2, 3130, Decimal('7.99'), datetime.datetime(2007, 2, 20, 17, 31, 48, 996577)),
#  (17508, 341, 1, 3382, Decimal('5.99'), datetime.datetime(2007, 2, 21, 12, 33, 49, 996577)),
#  (17509, 342, 2, 2190, Decimal('5.99'), datetime.datetime(2007, 2, 17, 23, 58, 17, 996577)),
#  (17510, 342, 1, 2914, Decimal('5.99'), datetime.datetime(2007, 2, 20, 2, 11, 44, 996577)),
#  (17511, 342, 1, 3081, Decimal('2.99'), datetime.datetime(2007, 2, 20, 13, 57, 39, 996577)),
#  (17512, 343, 2, 1547, Decimal('4.99'), datetime.datetime(2007, 2, 16, 0, 10, 50, 996577))]

# %%
# %%sql
#
# SELECT staff_id,
#     COUNT(*) AS count
# FROM payment
# GROUP BY staff_id
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 2 rows affected.
# [(2, 7304), (1, 7292)]

# %% [markdown]
# **GROUP BY** *(with multiple columns)*

# %%
# %%sql
#
# SELECT  customer_id,
#   staff_id,
#     COUNT(*)
# FROM payment
# GROUP BY customer_id, staff_id
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 1198 rows affected.
# [(448, 2, 16),
#  (459, 1, 22),
#  (460, 1, 10),
#  (236, 2, 20),
#  (282, 2, 13),
#  (112, 1, 13),
#  (499, 2, 13),
#  (1, 1, 15),
#  (388, 2, 19),
#  (594, 1, 13),
#  (59, 2, 10),
#  (478, 2, 10),
#  (234, 1, 11),
#  (6, 2, 10),
#  (160, 1, 13),
#  (384, 1, 7),
#  (211, 1, 10),
#  (146, 2, 11),
#  (141, 2, 13),
#  (555, 2, 9),
#  (150, 1, 9),
#  (534, 2, 12),
#  (175, 1, 11),
#  (155, 1, 15),
#  (207, 2, 18),
#  (227, 1, 10),
#  (63, 2, 13),
#  (287, 2, 16),
#  (110, 2, 5),
#  (589, 1, 11),
#  (19, 2, 8),
#  (522, 2, 20),
#  (397, 1, 12),
#  (593, 2, 13),
#  (342, 1, 15),
#  (559, 1, 17),
#  (478, 1, 9),
#  (84, 2, 20),
#  (21, 2, 16),
#  (457, 1, 17),
#  (539, 1, 8),
#  (4, 2, 10),
#  (26, 1, 21),
#  (530, 1, 12),
#  (95, 2, 10),
#  (203, 2, 12),
#  (559, 2, 11),
#  (476, 2, 8),
#  (460, 2, 11),
#  (171, 1, 9),
#  (52, 1, 13),
#  (575, 1, 9),
#  (372, 2, 13),
#  (367, 1, 9),
#  (251, 1, 10),
#  (463, 2, 9),
#  (25, 1, 17),
#  (334, 2, 10),
#  (80, 2, 15),
#  (408, 2, 16),
#  (307, 2, 4),
#  (282, 1, 7),
#  (177, 1, 12),
#  (510, 1, 9),
#  (331, 2, 6),
#  (304, 2, 8),
#  (185, 2, 7),
#  (555, 1, 8),
#  (138, 2, 11),
#  (315, 1, 7),
#  (382, 1, 10),
#  (322, 1, 9),
#  (83, 2, 13),
#  (159, 1, 7),
#  (226, 2, 6),
#  (195, 2, 11),
#  (20, 2, 16),
#  (180, 2, 8),
#  (588, 1, 14),
#  (169, 2, 12),
#  (137, 2, 16),
#  (486, 2, 14),
#  (588, 2, 13),
#  (500, 2, 12),
#  (318, 2, 3),
#  (553, 1, 10),
#  (215, 2, 16),
#  (597, 2, 9),
#  (247, 2, 6),
#  (222, 2, 10),
#  (284, 2, 8),
#  (246, 1, 9),
#  (179, 1, 17),
#  (139, 1, 14),
#  (591, 1, 16),
#  (291, 1, 6),
#  (466, 1, 12),
#  (382, 2, 12),
#  (392, 1, 10),
#  (165, 1, 9),
#  (456, 1, 15),
#  (548, 2, 8),
#  (419, 1, 13),
#  (210, 1, 10),
#  (264, 1, 17),
#  (564, 2, 15),
#  (104, 2, 9),
#  (573, 1, 17),
#  (28, 1, 13),
#  (589, 2, 14),
#  (152, 2, 7),
#  (238, 2, 5),
#  (409, 1, 11),
#  (77, 1, 10),
#  (119, 1, 13),
#  (507, 1, 11),
#  (289, 1, 8),
#  (200, 1, 14),
#  (41, 1, 12),
#  (235, 1, 11),
#  (363, 2, 16),
#  (451, 1, 16),
#  (55, 1, 10),
#  (134, 2, 11),
#  (243, 2, 12),
#  (274, 1, 13),
#  (595, 2, 13),
#  (483, 1, 8),
#  (347, 2, 18),
#  (308, 2, 7),
#  (57, 2, 15),
#  (320, 1, 4),
#  (10, 2, 12),
#  (312, 1, 15),
#  (407, 1, 13),
#  (234, 2, 14),
#  (337, 2, 12),
#  (12, 2, 18),
#  (362, 1, 18),
#  (342, 2, 17),
#  (474, 2, 10),
#  (293, 1, 11),
#  (320, 2, 11),
#  (309, 2, 14),
#  (179, 2, 9),
#  (243, 1, 11),
#  (236, 1, 19),
#  (201, 1, 8),
#  (407, 2, 13),
#  (448, 1, 11),
#  (156, 1, 9),
#  (172, 2, 16),
#  (79, 1, 10),
#  (399, 2, 11),
#  (125, 2, 11),
#  (221, 1, 16),
#  (499, 1, 16),
#  (274, 2, 14),
#  (504, 1, 11),
#  (303, 2, 10),
#  (63, 1, 12),
#  (270, 2, 8),
#  (53, 1, 13),
#  (205, 1, 9),
#  (491, 1, 11),
#  (489, 1, 11),
#  (174, 1, 12),
#  (368, 2, 14),
#  (201, 2, 14),
#  (9, 2, 8),
#  (281, 2, 6),
#  (533, 2, 12),
#  (81, 1, 13),
#  (413, 2, 9),
#  (537, 2, 11),
#  (126, 2, 12),
#  (265, 1, 13),
#  (250, 2, 5),
#  (333, 2, 14),
#  (177, 2, 11),
#  (275, 1, 9),
#  (163, 1, 12),
#  (122, 2, 16),
#  (86, 2, 18),
#  (273, 2, 13),
#  (226, 1, 15),
#  (302, 1, 11),
#  (210, 2, 20),
#  (370, 2, 10),
#  (27, 1, 15),
#  (117, 2, 5),
#  (465, 2, 6),
#  (390, 2, 15),
#  (190, 1, 11),
#  (5, 2, 21),
#  (471, 1, 15),
#  (222, 1, 6),
#  (237, 1, 11),
#  (213, 2, 15),
#  (103, 2, 15),
#  (443, 1, 12),
#  (389, 1, 15),
#  (467, 2, 13),
#  (365, 2, 9),
#  (204, 1, 15),
#  (94, 2, 9),
#  (361, 2, 15),
#  (574, 2, 6),
#  (524, 1, 7),
#  (268, 1, 5),
#  (247, 1, 13),
#  (144, 2, 19),
#  (35, 2, 8),
#  (467, 1, 15),
#  (151, 2, 12),
#  (147, 1, 12),
#  (150, 2, 13),
#  (160, 2, 14),
#  (142, 1, 13),
#  (172, 1, 14),
#  (319, 2, 11),
#  (33, 2, 5),
#  (184, 2, 10),
#  (11, 2, 11),
#  (412, 1, 10),
#  (490, 1, 11),
#  (374, 1, 9),
#  (15, 1, 17),
#  (509, 2, 10),
#  ...]

# %%
# %%sql
#
# SELECT staff_id,
#     COUNT(*) AS count
# FROM payment
# GROUP BY staff_id
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 2 rows affected.
# [(2, 7304), (1, 7292)]

# %% [markdown]
# **GROUP BY** with **ORDER BY**
# - order of columns doesn't matter in GROUP BY clause.
# - use ORDER BY after GROUP BY to control order

# %%
# %%sql
#
# SELECT  customer_id,
#   staff_id,
#     COUNT(*)
# FROM payment
# GROUP BY customer_id, staff_id
# ORDER BY customer_id, staff_id
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 1198 rows affected.
# [(1, 1, 15),
#  (1, 2, 15),
#  (2, 1, 14),
#  (2, 2, 12),
#  (3, 1, 12),
#  (3, 2, 12),
#  (4, 1, 12),
#  (4, 2, 10),
#  (5, 1, 14),
#  (5, 2, 21),
#  (6, 1, 15),
#  (6, 2, 10),
#  (7, 1, 16),
#  (7, 2, 12),
#  (8, 1, 14),
#  (8, 2, 9),
#  (9, 1, 12),
#  (9, 2, 8),
#  (10, 1, 12),
#  (10, 2, 12),
#  (11, 1, 12),
#  (11, 2, 11),
#  (12, 1, 8),
#  (12, 2, 18),
#  (13, 1, 17),
#  (13, 2, 10),
#  (14, 1, 16),
#  (14, 2, 7),
#  (15, 1, 17),
#  (15, 2, 15),
#  (16, 1, 10),
#  (16, 2, 15),
#  (17, 1, 9),
#  (17, 2, 9),
#  (18, 1, 5),
#  (18, 2, 14),
#  (19, 1, 10),
#  (19, 2, 8),
#  (20, 1, 11),
#  (20, 2, 16),
#  (21, 1, 16),
#  (21, 2, 16),
#  (22, 1, 15),
#  (22, 2, 4),
#  (23, 1, 11),
#  (23, 2, 16),
#  (24, 1, 12),
#  (24, 2, 11),
#  (25, 1, 17),
#  (25, 2, 10),
#  (26, 1, 21),
#  (26, 2, 11),
#  (27, 1, 15),
#  (27, 2, 15),
#  (28, 1, 13),
#  (28, 2, 17),
#  (29, 1, 20),
#  (29, 2, 15),
#  (30, 1, 18),
#  (30, 2, 16),
#  (31, 1, 10),
#  (31, 2, 16),
#  (32, 1, 13),
#  (32, 2, 13),
#  (33, 1, 15),
#  (33, 2, 5),
#  (34, 1, 13),
#  (34, 2, 11),
#  (35, 1, 22),
#  (35, 2, 8),
#  (36, 1, 10),
#  (36, 2, 15),
#  (37, 1, 11),
#  (37, 2, 10),
#  (38, 1, 16),
#  (38, 2, 18),
#  (39, 1, 13),
#  (39, 2, 16),
#  (40, 1, 13),
#  (40, 2, 13),
#  (41, 1, 12),
#  (41, 2, 13),
#  (42, 1, 16),
#  (42, 2, 13),
#  (43, 1, 11),
#  (43, 2, 11),
#  (44, 1, 10),
#  (44, 2, 11),
#  (45, 1, 16),
#  (45, 2, 10),
#  (46, 1, 14),
#  (46, 2, 17),
#  (47, 1, 9),
#  (47, 2, 10),
#  (48, 1, 5),
#  (48, 2, 9),
#  (49, 1, 12),
#  (49, 2, 12),
#  (50, 1, 12),
#  (50, 2, 18),
#  (51, 1, 20),
#  (51, 2, 10),
#  (52, 1, 13),
#  (52, 2, 15),
#  (53, 1, 13),
#  (53, 2, 11),
#  (54, 1, 15),
#  (54, 2, 11),
#  (55, 1, 10),
#  (55, 2, 9),
#  (56, 1, 13),
#  (56, 2, 13),
#  (57, 1, 11),
#  (57, 2, 15),
#  (58, 1, 13),
#  (58, 2, 11),
#  (59, 1, 14),
#  (59, 2, 10),
#  (60, 1, 14),
#  (446, 1, 12),
#  (446, 2, 16),
#  (447, 1, 14),
#  (447, 2, 13),
#  (448, 1, 11),
#  (448, 2, 16),
#  (449, 1, 7),
#  (449, 2, 10),
#  (450, 1, 15),
#  (450, 2, 10),
#  (451, 1, 16),
#  (451, 2, 14),
#  (452, 1, 17),
#  (452, 2, 12),
#  (453, 1, 11),
#  (453, 2, 12),
#  (454, 1, 13),
#  (454, 2, 19),
#  (455, 1, 12),
#  (455, 2, 10),
#  (456, 1, 15),
#  (456, 2, 9),
#  (457, 1, 17),
#  (457, 2, 10),
#  (458, 1, 6),
#  (458, 2, 13),
#  (459, 1, 22),
#  (459, 2, 15),
#  (460, 1, 10),
#  (460, 2, 11),
#  (461, 1, 10),
#  (461, 2, 17),
#  (462, 1, 21),
#  (462, 2, 10),
#  (463, 1, 15),
#  (463, 2, 9),
#  (464, 1, 8),
#  (464, 2, 6),
#  (465, 1, 10),
#  (465, 2, 6),
#  (466, 1, 12),
#  (466, 2, 10),
#  (467, 1, 15),
#  (467, 2, 13),
#  (468, 1, 17),
#  (468, 2, 17),
#  (469, 1, 19),
#  (469, 2, 16),
#  (470, 1, 18),
#  (470, 2, 13),
#  (471, 1, 15),
#  (471, 2, 11),
#  (472, 1, 14),
#  (472, 2, 12),
#  (473, 1, 12),
#  (473, 2, 19),
#  (474, 1, 15),
#  (474, 2, 10),
#  (475, 1, 15),
#  (475, 2, 7),
#  (476, 1, 12),
#  (476, 2, 8),
#  (477, 1, 9),
#  (477, 2, 12),
#  (478, 1, 9),
#  (478, 2, 10),
#  (479, 1, 11),
#  (479, 2, 18),
#  (480, 1, 7),
#  (480, 2, 12),
#  (481, 1, 14),
#  (481, 2, 14),
#  (482, 1, 8),
#  (482, 2, 18),
#  (483, 1, 8),
#  (483, 2, 9),
#  (484, 1, 13),
#  (484, 2, 14),
#  (485, 1, 14),
#  (485, 2, 14),
#  (486, 1, 9),
#  (486, 2, 14),
#  (487, 1, 12),
#  (487, 2, 14),
#  (488, 1, 8),
#  (488, 2, 14),
#  (489, 1, 11),
#  (489, 2, 8),
#  (490, 1, 11),
#  (490, 2, 11),
#  (491, 1, 11),
#  (491, 2, 14),
#  (492, 1, 6),
#  (492, 2, 9),
#  (493, 1, 14),
#  (493, 2, 8),
#  (494, 1, 11),
#  (494, 2, 19),
#  (495, 1, 12),
#  (495, 2, 12),
#  (496, 1, 12),
#  (496, 2, 7),
#  (497, 1, 15),
#  (497, 2, 12),
#  (498, 1, 16),
#  (498, 2, 8),
#  (499, 1, 16),
#  (499, 2, 13),
#  (500, 1, 13),
#  (500, 2, 12),
#  ...]

# %%
# %%sql
#
# SELECT  customer_id,
#   staff_id,
#     COUNT(*)
# FROM payment
# GROUP BY customer_id, staff_id
# ORDER BY staff_id, customer_id
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 
#  (313, 2, 11),
#  (314, 2, 18),
#  (315, 2, 7),
#  (316, 2, 10),
#  (317, 2, 9),
#  (318, 2, 3),
#  (319, 2, 11),
#  (320, 2, 11),
#  (321, 2, 9),
#  (322, 2, 10),
#  (323, 2, 11),
#  (324, 2, 10),
#  (325, 2, 12),
#  (326, 2, 12),
#  (327, 2, 6),
#  (328, 2, 6),
#  (329, 2, 11),
#  (330, 2, 9),
#  (331, 2, 6),
#  (332, 2, 15),
#  (333, 2, 14),
#  (334, 2, 10),
#  (335, 2, 10),
#  (336, 2, 15),
#  (337, 2, 12),
#  (338, 2, 10),
#  (339, 2, 11),
#  (340, 2, 11),
#  (341, 2, 14),
#  (342, 2, 17),
#  (343, 2, 14),
#  (344, 2, 11),
#  (345, 2, 12),
#  (346, 2, 17),
#  (347, 2, 18),
#  (348, 2, 21),
#  (349, 2, 11),
#  (350, 2, 11),
#  (351, 2, 11),
#  (352, 2, 8),
#  (353, 2, 12),
#  (354, 2, 14),
#  (355, 2, 9),
#  (356, 2, 12),
#  (357, 2, 11),
#  (358, 2, 5),
#  (359, 2, 10),
#  (360, 2, 17),
#  (361, 2, 15),
#  (362, 2, 13),
#  (363, 2, 16),
#  (364, 2, 12),
#  (365, 2, 9),
#  (366, 2, 16),
#  (367, 2, 11),
#  (368, 2, 14),
#  (369, 2, 11),
#  (370, 2, 10),
#  (371, 2, 10),
#  (372, 2, 13),
#  (373, 2, 15),
#  (374, 2, 16),
#  (375, 2, 8),
#  (376, 2, 7),
#  (377, 2, 10),
#  (378, 2, 8),
#  (379, 2, 7),
#  (380, 2, 13),
#  (381, 2, 20),
#  (382, 2, 12),
#  (383, 2, 11),
#  (384, 2, 14),
#  (385, 2, 7),
#  (386, 2, 12),
#  (387, 2, 13),
#  (388, 2, 19),
#  (389, 2, 10),
#  (390, 2, 15),
#  (391, 2, 9),
#  (392, 2, 13),
#  (393, 2, 18),
#  (394, 2, 10),
#  (395, 2, 5),
#  (396, 2, 19),
#  (397, 2, 16),
#  (398, 2, 9),
#  (399, 2, 11),
#  (400, 2, 15),
#  (401, 2, 8),
#  ...]

# %% [markdown]
# **GROUP BY** with **LIMIT**

# %%
# %%sql
#
# SELECT  customer_id,
#   staff_id,
#     COUNT(*)
# FROM payment
# GROUP BY customer_id, staff_id
# ORDER BY staff_id, customer_id
# LIMIT 10
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 10 rows affected.
# [(1, 1, 15),
#  (2, 1, 14),
#  (3, 1, 12),
#  (4, 1, 12),
#  (5, 1, 14),
#  (6, 1, 15),
#  (7, 1, 16),
#  (8, 1, 14),
#  (9, 1, 12),
#  (10, 1, 12)]

# %% [markdown]
# ### 3. HAVING

# %%
# %%sql
#
# SELECT *
# FROM payment
# LIMIT 10
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 10 rows affected.
# [(17503, 341, 2, 1520, Decimal('7.99'), datetime.datetime(2007, 2, 15, 22, 25, 46, 996577)),
#  (17504, 341, 1, 1778, Decimal('1.99'), datetime.datetime(2007, 2, 16, 17, 23, 14, 996577)),
#  (17505, 341, 1, 1849, Decimal('7.99'), datetime.datetime(2007, 2, 16, 22, 41, 45, 996577)),
#  (17506, 341, 2, 2829, Decimal('2.99'), datetime.datetime(2007, 2, 19, 19, 39, 56, 996577)),
#  (17507, 341, 2, 3130, Decimal('7.99'), datetime.datetime(2007, 2, 20, 17, 31, 48, 996577)),
#  (17508, 341, 1, 3382, Decimal('5.99'), datetime.datetime(2007, 2, 21, 12, 33, 49, 996577)),
#  (17509, 342, 2, 2190, Decimal('5.99'), datetime.datetime(2007, 2, 17, 23, 58, 17, 996577)),
#  (17510, 342, 1, 2914, Decimal('5.99'), datetime.datetime(2007, 2, 20, 2, 11, 44, 996577)),
#  (17511, 342, 1, 3081, Decimal('2.99'), datetime.datetime(2007, 2, 20, 13, 57, 39, 996577)),
#  (17512, 343, 2, 1547, Decimal('4.99'), datetime.datetime(2007, 2, 16, 0, 10, 50, 996577))]

# %% [markdown]
# ***WHERE clause doesn't allow to filter on aggregate columns, instead use HAVING***

# %%
# %%sql
#
# SELECT  customer_id,
#   staff_id,
#     MAX(amount) as max_amount
# FROM payment
# GROUP BY customer_id, staff_id
# HAVING MAX(amount) < 5
# ORDER BY staff_id, customer_id
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 56 rows affected.
# [(43, 1, Decimal('4.99')),
#  (72, 1, Decimal('4.99')),
#  (91, 1, Decimal('4.99')),
#  (97, 1, Decimal('4.99')),
#  (99, 1, Decimal('4.99')),
#  (109, 1, Decimal('4.99')),
#  (118, 1, Decimal('4.99')),
#  (175, 1, Decimal('4.99')),
#  (215, 1, Decimal('2.99')),
#  (220, 1, Decimal('4.99')),
#  (248, 1, Decimal('3.99')),
#  (271, 1, Decimal('4.99')),
#  (281, 1, Decimal('3.99')),
#  (289, 1, Decimal('4.99')),
#  (320, 1, Decimal('2.99')),
#  (344, 1, Decimal('3.99')),
#  (359, 1, Decimal('4.99')),
#  (381, 1, Decimal('4.99')),
#  (418, 1, Decimal('4.99')),
#  (420, 1, Decimal('4.99')),
#  (473, 1, Decimal('4.99')),
#  (543, 1, Decimal('4.99')),
#  (551, 1, Decimal('4.99')),
#  (557, 1, Decimal('4.99')),
#  (568, 1, Decimal('4.99')),
#  (586, 1, Decimal('4.99')),
#  (588, 1, Decimal('4.99')),
#  (8, 2, Decimal('4.99')),
#  (35, 2, Decimal('4.99')),
#  (73, 2, Decimal('4.99')),
#  (91, 2, Decimal('4.99')),
#  (94, 2, Decimal('4.99')),
#  (115, 2, Decimal('4.99')),
#  (134, 2, Decimal('4.99')),
#  (138, 2, Decimal('4.99')),
#  (151, 2, Decimal('3.99')),
#  (157, 2, Decimal('4.99')),
#  (198, 2, Decimal('4.99')),
#  (227, 2, Decimal('4.99')),
#  (264, 2, Decimal('3.99')),
#  (283, 2, Decimal('4.99')),
#  (288, 2, Decimal('3.99')),
#  (320, 2, Decimal('4.99')),
#  (326, 2, Decimal('4.99')),
#  (330, 2, Decimal('4.99')),
#  (335, 2, Decimal('4.99')),
#  (340, 2, Decimal('4.99')),
#  (397, 2, Decimal('4.99')),
#  (428, 2, Decimal('4.99')),
#  (435, 2, Decimal('4.99')),
#  (450, 2, Decimal('4.99')),
#  (498, 2, Decimal('4.99')),
#  (499, 2, Decimal('4.99')),
#  (527, 2, Decimal('4.99')),
#  (580, 2, Decimal('4.99')),
#  (596, 2, Decimal('4.99'))]

# %% [markdown]
# *Query clause order*
# - SELECT
# - FROM
# - WHERE
# - GROUP BY
# - HAVING
# - ORDER BY

# %% [markdown]
# ### 4. CASE

# %% [markdown]
# **CASE** *with single condition*

# %%
# %%sql
#
# SELECT title,
# rating,
# CASE WHEN rating = 'NC-17' THEN 'yes'
# ELSE NULL END AS is_under_17
# FROM film
# LIMIT 20
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 20 rows affected.
# [('Chamber Italian', 'NC-17', 'yes'),
#  ('Grosse Wonderful', 'R', None),
#  ('Airport Pollock', 'R', None),
#  ('Bright Encounters', 'PG-13', None),
#  ('Academy Dinosaur', 'PG', None),
#  ('Ace Goldfinger', 'G', None),
#  ('Adaptation Holes', 'NC-17', 'yes'),
#  ('Affair Prejudice', 'G', None),
#  ('African Egg', 'G', None),
#  ('Agent Truman', 'PG', None),
#  ('Airplane Sierra', 'PG-13', None),
#  ('Alabama Devil', 'PG-13', None),
#  ('Aladdin Calendar', 'NC-17', 'yes'),
#  ('Alamo Videotape', 'G', None),
#  ('Alaska Phantom', 'PG', None),
#  ('Date Speed', 'R', None),
#  ('Ali Forever', 'PG', None),
#  ('Alice Fantasia', 'NC-17', 'yes'),
#  ('Alien Center', 'NC-17', 'yes'),
#  ('Alley Evolution', 'NC-17', 'yes')]

# %% [markdown]
# **CASE** *with single condition*

# %%
# %%sql
#
# SELECT title,
# rating,
# CASE WHEN rating = 'NC-17' THEN 'yes'
#     ELSE 'no' END AS is_under_17
# FROM film
# LIMIT 20
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 20 rows affected.
# [('Chamber Italian', 'NC-17', 'yes'),
#  ('Grosse Wonderful', 'R', 'no'),
#  ('Airport Pollock', 'R', 'no'),
#  ('Bright Encounters', 'PG-13', 'no'),
#  ('Academy Dinosaur', 'PG', 'no'),
#  ('Ace Goldfinger', 'G', 'no'),
#  ('Adaptation Holes', 'NC-17', 'yes'),
#  ('Affair Prejudice', 'G', 'no'),
#  ('African Egg', 'G', 'no'),
#  ('Agent Truman', 'PG', 'no'),
#  ('Airplane Sierra', 'PG-13', 'no'),
#  ('Alabama Devil', 'PG-13', 'no'),
#  ('Aladdin Calendar', 'NC-17', 'yes'),
#  ('Alamo Videotape', 'G', 'no'),
#  ('Alaska Phantom', 'PG', 'no'),
#  ('Date Speed', 'R', 'no'),
#  ('Ali Forever', 'PG', 'no'),
#  ('Alice Fantasia', 'NC-17', 'yes'),
#  ('Alien Center', 'NC-17', 'yes'),
#  ('Alley Evolution', 'NC-17', 'yes')]

# %% [markdown]
# **CASE** *with multiple condition*

# %%
# %%sql
#
# SELECT title,
# length,
# CASE WHEN length < 50 THEN 'under 50'
#     WHEN (length > 50 AND length < 100) THEN 'b/w 50-100'
#     WHEN (length > 100 AND length < 150) THEN 'b/w 100-150'
#     ELSE 'over 150' END AS length_group
# FROM film
# LIMIT 20
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 20 rows affected.
# [('Chamber Italian', 117, 'b/w 100-150'),
#  ('Grosse Wonderful', 49, 'under 50'),
#  ('Airport Pollock', 54, 'b/w 50-100'),
#  ('Bright Encounters', 73, 'b/w 50-100'),
#  ('Academy Dinosaur', 86, 'b/w 50-100'),
#  ('Ace Goldfinger', 48, 'under 50'),
#  ('Adaptation Holes', 50, 'over 150'),
#  ('Affair Prejudice', 117, 'b/w 100-150'),
#  ('African Egg', 130, 'b/w 100-150'),
#  ('Agent Truman', 169, 'over 150'),
#  ('Airplane Sierra', 62, 'b/w 50-100'),
#  ('Alabama Devil', 114, 'b/w 100-150'),
#  ('Aladdin Calendar', 63, 'b/w 50-100'),
#  ('Alamo Videotape', 126, 'b/w 100-150'),
#  ('Alaska Phantom', 136, 'b/w 100-150'),
#  ('Date Speed', 104, 'b/w 100-150'),
#  ('Ali Forever', 150, 'over 150'),
#  ('Alice Fantasia', 94, 'b/w 50-100'),
#  ('Alien Center', 46, 'under 50'),
#  ('Alley Evolution', 180, 'over 150')]

# %%
# %%sql
#
# SELECT title,
# length,
# CASE WHEN length < 50 THEN 'under 50'
#     ELSE NULL END AS length_group
# FROM film
# LIMIT 20
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 20 rows affected.
# [('Chamber Italian', 117, None),
#  ('Grosse Wonderful', 49, 'under 50'),
#  ('Airport Pollock', 54, None),
#  ('Bright Encounters', 73, None),
#  ('Academy Dinosaur', 86, None),
#  ('Ace Goldfinger', 48, 'under 50'),
#  ('Adaptation Holes', 50, None),
#  ('Affair Prejudice', 117, None),
#  ('African Egg', 130, None),
#  ('Agent Truman', 169, None),
#  ('Airplane Sierra', 62, None),
#  ('Alabama Devil', 114, None),
#  ('Aladdin Calendar', 63, None),
#  ('Alamo Videotape', 126, None),
#  ('Alaska Phantom', 136, None),
#  ('Date Speed', 104, None),
#  ('Ali Forever', 150, None),
#  ('Alice Fantasia', 94, None),
#  ('Alien Center', 46, 'under 50'),
#  ('Alley Evolution', 180, None)]

# %% [markdown]
# **CASE** *with aggregate function & single condition.*

# %%
# %%sql
#
# SELECT CASE WHEN rental_rate < 3 THEN 'under 3$'
#     ELSE 'over 3$' END AS rental_rate_group,
#     COUNT(*) AS count
# FROM film
# GROUP BY CASE WHEN rental_rate < 3 THEN 'under 3$'
#     ELSE 'over 3$' END
# LIMIT 20
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 2 rows affected.
# [('over 3$', 336), ('under 3$', 664)]

# %%
# %%sql
#
# SELECT CASE WHEN rental_rate < 3 THEN 'under 3$'
#     ELSE 'over 3$' END AS rental_rate_group,
#     COUNT(*) AS count
# FROM film
# GROUP BY rental_rate_group
# LIMIT 20
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 2 rows affected.
# [('over 3$', 336), ('under 3$', 664)]

# %% [markdown]
# **CASE** *with aggregate function & multiple condition using alias name in GROUP BY*

# %%
# %%sql
#
# SELECT CASE WHEN rental_rate < 2 THEN 'under 2$'
#     WHEN (rental_rate > 2 AND rental_rate < 4) THEN 'b/w 2\$ & 4\$'
#     ELSE 'over 4$' END AS rental_rate_group,
#     COUNT(*) AS count
# FROM film
# GROUP BY rental_rate_group
# LIMIT 20
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 3 rows affected.
# [('b/w 2\\$ & 4\\$', 323), ('under 2$', 341), ('over 4$', 336)]

# %% [markdown]
# **CASE** *with aggregate function & multiple condition using CASE statements in GROUP BY*

# %%
# %%sql
#
# SELECT CASE WHEN rental_rate < 2 THEN 'under 2$'
#     WHEN (rental_rate > 2 AND rental_rate < 4) THEN 'b/w 2\$ & 4\$'
#     ELSE 'over 4$' END AS rental_rate_group,
#     COUNT(*) AS count
# FROM film
# GROUP BY CASE WHEN rental_rate < 2 THEN 'under 2$'
#     WHEN (rental_rate > 2 AND rental_rate < 4) THEN 'b/w 2\$ & 4\$'
#     ELSE 'over 4$' END
# LIMIT 20
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 3 rows affected.
# [('b/w 2\\$ & 4\\$', 323), ('under 2$', 341), ('over 4$', 336)]

# %%
# %%sql
#
# SELECT CASE WHEN rental_rate < 2 THEN 'under 2$'
#     WHEN (rental_rate > 2 AND rental_rate < 4) THEN 'b/w 2\$ & 4\$'
#     ELSE 'over 4$' END AS rental_rate_group,
#     *
# FROM film
#
# LIMIT 20
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 20 rows affected.
# [('over 4$', 133, 'Chamber Italian', 'A Fateful Reflection of a Moose And a Husband who must Overcome a Monkey in Nigeria', 2006, 1, 7, Decimal('4.99'), 117, Decimal('14.99'), 'NC-17', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers'], "'chamber':1 'fate':4 'husband':11 'italian':2 'monkey':16 'moos':8 'must':13 'nigeria':18 'overcom':14 'reflect':5"),
#  ('over 4$', 384, 'Grosse Wonderful', 'A Epic Drama of a Cat And a Explorer who must Redeem a Moose in Australia', 2006, 1, 5, Decimal('4.99'), 49, Decimal('19.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Behind the Scenes'], "'australia':18 'cat':8 'drama':5 'epic':4 'explor':11 'gross':1 'moos':16 'must':13 'redeem':14 'wonder':2"),
#  ('over 4$', 8, 'Airport Pollock', 'A Epic Tale of a Moose And a Girl who must Confront a Monkey in Ancient India', 2006, 1, 6, Decimal('4.99'), 54, Decimal('15.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers'], "'airport':1 'ancient':18 'confront':14 'epic':4 'girl':11 'india':19 'monkey':16 'moos':8 'must':13 'pollock':2 'tale':5"),
#  ('over 4$', 98, 'Bright Encounters', 'A Fateful Yarn of a Lumberjack And a Feminist who must Conquer a Student in A Jet Boat', 2006, 1, 4, Decimal('4.99'), 73, Decimal('12.99'), 'PG-13', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers'], "'boat':20 'bright':1 'conquer':14 'encount':2 'fate':4 'feminist':11 'jet':19 'lumberjack':8 'must':13 'student':16 'yarn':5"),
#  ('under 2$', 1, 'Academy Dinosaur', 'A Epic Drama of a Feminist And a Mad Scientist who must Battle a Teacher in The Canadian Rockies', 2006, 1, 6, Decimal('0.99'), 86, Decimal('20.99'), 'PG', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Deleted Scenes', 'Behind the Scenes'], "'academi':1 'battl':15 'canadian':20 'dinosaur':2 'drama':5 'epic':4 'feminist':8 'mad':11 'must':14 'rocki':21 'scientist':12 'teacher':17"),
#  ('over 4$', 2, 'Ace Goldfinger', 'A Astounding Epistle of a Database Administrator And a Explorer who must Find a Car in Ancient China', 2006, 1, 3, Decimal('4.99'), 48, Decimal('12.99'), 'G', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Deleted Scenes'], "'ace':1 'administr':9 'ancient':19 'astound':4 'car':17 'china':20 'databas':8 'epistl':5 'explor':12 'find':15 'goldfing':2 'must':14"),
#  ('b/w 2\\$ & 4\\$', 3, 'Adaptation Holes', 'A Astounding Reflection of a Lumberjack And a Car who must Sink a Lumberjack in A Baloon Factory', 2006, 1, 7, Decimal('2.99'), 50, Decimal('18.99'), 'NC-17', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Deleted Scenes'], "'adapt':1 'astound':4 'baloon':19 'car':11 'factori':20 'hole':2 'lumberjack':8,16 'must':13 'reflect':5 'sink':14"),
#  ('b/w 2\\$ & 4\\$', 4, 'Affair Prejudice', 'A Fanciful Documentary of a Frisbee And a Lumberjack who must Chase a Monkey in A Shark Tank', 2006, 1, 5, Decimal('2.99'), 117, Decimal('26.99'), 'G', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries', 'Behind the Scenes'], "'affair':1 'chase':14 'documentari':5 'fanci':4 'frisbe':8 'lumberjack':11 'monkey':16 'must':13 'prejudic':2 'shark':19 'tank':20"),
#  ('b/w 2\\$ & 4\\$', 5, 'African Egg', 'A Fast-Paced Documentary of a Pastry Chef And a Dentist who must Pursue a Forensic Psychologist in The Gulf of Mexico', 2006, 1, 6, Decimal('2.99'), 130, Decimal('22.99'), 'G', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Deleted Scenes'], "'african':1 'chef':11 'dentist':14 'documentari':7 'egg':2 'fast':5 'fast-pac':4 'forens':19 'gulf':23 'mexico':25 'must':16 'pace':6 'pastri':10 'psychologist':20 'pursu':17"),
#  ('b/w 2\\$ & 4\\$', 6, 'Agent Truman', 'A Intrepid Panorama of a Robot And a Boy who must Escape a Sumo Wrestler in Ancient China', 2006, 1, 3, Decimal('2.99'), 169, Decimal('17.99'), 'PG', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Deleted Scenes'], "'agent':1 'ancient':19 'boy':11 'china':20 'escap':14 'intrepid':4 'must':13 'panorama':5 'robot':8 'sumo':16 'truman':2 'wrestler':17"),
#  ('over 4$', 7, 'Airplane Sierra', 'A Touching Saga of a Hunter And a Butler who must Discover a Butler in A Jet Boat', 2006, 1, 6, Decimal('4.99'), 62, Decimal('28.99'), 'PG-13', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Deleted Scenes'], "'airplan':1 'boat':20 'butler':11,16 'discov':14 'hunter':8 'jet':19 'must':13 'saga':5 'sierra':2 'touch':4"),
#  ('b/w 2\\$ & 4\\$', 9, 'Alabama Devil', 'A Thoughtful Panorama of a Database Administrator And a Mad Scientist who must Outgun a Mad Scientist in A Jet Boat', 2006, 1, 3, Decimal('2.99'), 114, Decimal('21.99'), 'PG-13', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Deleted Scenes'], "'administr':9 'alabama':1 'boat':23 'databas':8 'devil':2 'jet':22 'mad':12,18 'must':15 'outgun':16 'panorama':5 'scientist':13,19 'thought':4"),
#  ('over 4$', 10, 'Aladdin Calendar', 'A Action-Packed Tale of a Man And a Lumberjack who must Reach a Feminist in Ancient China', 2006, 1, 6, Decimal('4.99'), 63, Decimal('24.99'), 'NC-17', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Deleted Scenes'], "'action':5 'action-pack':4 'aladdin':1 'ancient':20 'calendar':2 'china':21 'feminist':18 'lumberjack':13 'man':10 'must':15 'pack':6 'reach':16 'tale':7"),
#  ('under 2$', 11, 'Alamo Videotape', 'A Boring Epistle of a Butler And a Cat who must Fight a Pastry Chef in A MySQL Convention', 2006, 1, 6, Decimal('0.99'), 126, Decimal('16.99'), 'G', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries', 'Behind the Scenes'], "'alamo':1 'bore':4 'butler':8 'cat':11 'chef':17 'convent':21 'epistl':5 'fight':14 'must':13 'mysql':20 'pastri':16 'videotap':2"),
#  ('under 2$', 12, 'Alaska Phantom', 'A Fanciful Saga of a Hunter And a Pastry Chef who must Vanquish a Boy in Australia', 2006, 1, 6, Decimal('0.99'), 136, Decimal('22.99'), 'PG', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries', 'Deleted Scenes'], "'alaska':1 'australia':19 'boy':17 'chef':12 'fanci':4 'hunter':8 'must':14 'pastri':11 'phantom':2 'saga':5 'vanquish':15"),
#  ('under 2$', 213, 'Date Speed', 'A Touching Saga of a Composer And a Moose who must Discover a Dentist in A MySQL Convention', 2006, 1, 4, Decimal('0.99'), 104, Decimal('19.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries'], "'compos':8 'convent':20 'date':1 'dentist':16 'discov':14 'moos':11 'must':13 'mysql':19 'saga':5 'speed':2 'touch':4"),
#  ('over 4$', 13, 'Ali Forever', 'A Action-Packed Drama of a Dentist And a Crocodile who must Battle a Feminist in The Canadian Rockies', 2006, 1, 4, Decimal('4.99'), 150, Decimal('21.99'), 'PG', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Deleted Scenes', 'Behind the Scenes'], "'action':5 'action-pack':4 'ali':1 'battl':16 'canadian':21 'crocodil':13 'dentist':10 'drama':7 'feminist':18 'forev':2 'must':15 'pack':6 'rocki':22"),
#  ('under 2$', 14, 'Alice Fantasia', 'A Emotional Drama of a A Shark And a Database Administrator who must Vanquish a Pioneer in Soviet Georgia', 2006, 1, 6, Decimal('0.99'), 94, Decimal('23.99'), 'NC-17', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Deleted Scenes', 'Behind the Scenes'], "'administr':13 'alic':1 'databas':12 'drama':5 'emot':4 'fantasia':2 'georgia':21 'must':15 'pioneer':18 'shark':9 'soviet':20 'vanquish':16"),
#  ('b/w 2\\$ & 4\\$', 15, 'Alien Center', 'A Brilliant Drama of a Cat And a Mad Scientist who must Battle a Feminist in A MySQL Convention', 2006, 1, 5, Decimal('2.99'), 46, Decimal('10.99'), 'NC-17', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries', 'Behind the Scenes'], "'alien':1 'battl':15 'brilliant':4 'cat':8 'center':2 'convent':21 'drama':5 'feminist':17 'mad':11 'must':14 'mysql':20 'scientist':12"),
#  ('b/w 2\\$ & 4\\$', 16, 'Alley Evolution', 'A Fast-Paced Drama of a Robot And a Composer who must Battle a Astronaut in New Orleans', 2006, 1, 6, Decimal('2.99'), 180, Decimal('23.99'), 'NC-17', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries'], "'alley':1 'astronaut':18 'battl':16 'compos':13 'drama':7 'evolut':2 'fast':5 'fast-pac':4 'must':15 'new':20 'orlean':21 'pace':6 'robot':10")]

# %% [markdown]
# **CASE** inside of aggregate functions. *(shows data horizontally)*

# %% [markdown]
# ### 5. DISTINCT

# %% [markdown]
# ***on single column***

# %%
# %%sql
#
# SELECT DISTINCT(rating)
# FROM film
# LIMIT 10
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 5 rows affected.
# [('R',), ('NC-17',), ('G',), ('PG',), ('PG-13',)]

# %% [markdown]
# ***on multiple columns*** *(eg- 2 columns below gives unique pairs of them)*

# %%
# %%sql
#
# SELECT DISTINCT rating, special_features
# FROM film
# LIMIT 10
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 10 rows affected.
# [('R', ['Trailers', 'Commentaries', 'Behind the Scenes']),
#  ('R', ['Behind the Scenes']),
#  ('PG-13', ['Commentaries', 'Behind the Scenes']),
#  ('PG', ['Deleted Scenes', 'Behind the Scenes']),
#  ('R', ['Commentaries', 'Behind the Scenes']),
#  ('G', ['Behind the Scenes']),
#  ('PG-13', ['Deleted Scenes']),
#  ('G', ['Commentaries', 'Deleted Scenes', 'Behind the Scenes']),
#  ('PG-13', ['Trailers', 'Behind the Scenes']),
#  ('G', ['Commentaries'])]

# %% [markdown]
# **DISTINCT** in aggregations.

# %%
# %%sql
#
# SELECT COUNT(DISTINCT rating) AS unique_ratings
#
# FROM film
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 1 rows affected.
# [(5,)]
